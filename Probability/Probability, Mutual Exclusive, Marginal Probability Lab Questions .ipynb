# %% [markdown]
# # Problems on Probability
#
# **1. A bag contains 5 red balls, 3 green balls, and 2 blue balls. You randomly draw one ball from the bag.**
#
# - a) What is the probability of drawing a red ball?
#
# - b) What is the probability of drawing a green ball?
#
# - c) What is the probability of not drawing a blue ball?

# %%
# write the answers
#What is the probability of drawing a red ball?
total=10
red=5
green=3
blue=2
red_ball_prob=5/10
#What is the probability of drawing a green ball?
green_ball=3/10
# What is the probability of not drawing a blue ball?
not_blue_ball= 1-(2/10)

# %% [markdown]
# **Mutually Exclusive Events Problem**
#
# **2: If P(A) = 0.20, P(A ∪ B) = 0.51, and A and B are mutually exclusive events then find P(B)**`

# %%
# write the answers

# %% [markdown]
# **3. A box contains 5 red balls and 5 blue balls. If you randomly pick one ball from the box, what is the probability that the ball is either red or blue?**

# %%
# write the answers

# %% [markdown]
# **Not Mutually Exclusive Events Problem**
#
#
# **4. In a deck of 52 cards, what is the probability of drawing a card that is either a king or a heart?**

# %%
# write the answers

# %% [markdown]
# **Marginal Probability Example**
#
# A survey was conducted among 100 people to find out their preference for two types of beverages: coffee and tea. The survey results are summarized in the Below table:
#
# **5. What is the marginal probability that a randomly selected person from the survey likes coffee?**

# %%
import pandas as pd

# Create the data for the table
data = {
    "Likes Coffee": [20, 25, 45],
    "Likes Tea": [30, 25, 55],
    "Total": [50, 50, 100]
}

# Create the index for the table
index = ["Male", "Female", "Total"]

# Create the DataFrame
df = pd.DataFrame(data, index=index)

df
# Out:
#         Likes Coffee  Likes Tea  Total
# Male              20         30     50
# Female            25         25     50
# Total             45         55    100

# %%
# write the answers

# %% [markdown]
# **6. Using the same survey data, are the events "being female" and "liking coffee" independent?**
#
# Two events A and B are independent if the occurrence of one event does not affect the probability of the occurrence of the other event. Mathematically, events A and B are independent if:
#
# P(A∩B)=P(A)⋅P(B)

# %%
# write the answers
