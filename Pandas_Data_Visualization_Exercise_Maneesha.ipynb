# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
data = np.random.rand(500, 4)
df3 = pd.DataFrame(data, columns=['a', 'b', 'c', 'd'])
df3
# df3 = pd.read_csv('df3')
# %matplotlib inline
# Out:
#             a         b         c         d
# 0    0.374540  0.950714  0.731994  0.598658
# 1    0.156019  0.155995  0.058084  0.866176
# 2    0.601115  0.708073  0.020584  0.969910
# 3    0.832443  0.212339  0.181825  0.183405
# 4    0.304242  0.524756  0.431945  0.291229
# ..        ...       ...       ...       ...
# 495  0.186101  0.802643  0.458187  0.482969
# 496  0.133480  0.080602  0.727939  0.496461
# 497  0.436851  0.729508  0.765513  0.158908
# 498  0.610225  0.135354  0.751375  0.656955
# 499  0.956615  0.068958  0.057055  0.282187
#
# [500 rows x 4 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.7 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.374540  0.950714  0.731994  0.598658
# 1  0.156019  0.155995  0.058084  0.866176
# 2  0.601115  0.708073  0.020584  0.969910
# 3  0.832443  0.212339  0.181825  0.183405
# 4  0.304242  0.524756  0.431945  0.291229

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
fig = plt.figure(figsize=(10, 3))
plt.scatter(df3['b'], df3['a'], color = 'red', edgecolors='black')
plt.xlim(-0.2, 1.2)
plt.ylim(-0.2, 1.2)
plt.xlabel('a')
plt.ylabel('b')
plt.show()

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
plt.hist(df3['a'], color = 'b', edgecolor='black')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
plt.hist(df3['a'], color = '#FF9999', edgecolor='white', bins = 25)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3.boxplot(column=['a', 'b'], figsize=(6, 4), whiskerprops=dict(color='red', linestyle='--'))
# Out:
# <Axes: >

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
import seaborn as sns

sns.kdeplot(df3['d'])
# Out:
# <Axes: xlabel='d', ylabel='Density'>

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
sns.kdeplot(df3['d'], linestyle = '--', linewidth = 4)
# Out:
# <Axes: xlabel='d', ylabel='Density'>

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
# df3.plot.area(xlim = (0, 30))
df3.iloc[:31].plot.area()
plt.legend(loc = 'upper left')

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
df3.plot.area(xlim = (0, 30))

plt.legend(bbox_to_anchor=(1.15, 0.5), loc='center right')

# %% [markdown]
# # Great Job!
